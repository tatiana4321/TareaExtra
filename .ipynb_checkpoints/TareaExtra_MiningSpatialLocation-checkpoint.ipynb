# %% [markdown]
# #Data

# %%
from fiona import listlayers

russiaMapsLink="https://github.com/tatiana4321/TareaExtra/raw/main/RusiaMaps_3576.gpkg"
#layers in maps
listlayers(russiaMapsLink)
# Out:
# ['country', 'cities', 'rivers', 'airports']

# %% [markdown]
# Let's read in the data:

# %%
import geopandas as gpd

country=gpd.read_file(russiaMapsLink,layer='country')
cities=gpd.read_file(russiaMapsLink,layer='cities')
rivers=gpd.read_file(russiaMapsLink,layer='rivers')
airports=gpd.read_file(russiaMapsLink,layer='airports')

# %% [markdown]
# Adding seaports data. Let's read the UpdatedPub150.csv from the GitHub repo:

# %%
import pandas as pd

portsFileLink="https://github.com/tatiana4321/TareaExtra/raw/main/UpdatedPub150.csv"
infoseaports=pd.read_csv(portsFileLink)

#columns available (so many)
infoseaports.columns.to_list()
# Out:
# ['OID_',
#  'World Port Index Number',
#  'Region Name',
#  'Main Port Name',
#  'Alternate Port Name',
#  'UN/LOCODE',
#  'Country Code',
#  'World Water Body',
#  'IHO S-130 Sea Area',
#  'Sailing Direction or Publication',
#  'Publication Link',
#  'Standard Nautical Chart',
#  'IHO S-57 Electronic Navigational Chart',
#  'IHO S-101 Electronic Navigational Chart',
#  'Digital Nautical Chart',
#  'Tidal Range (m)',
#  'Entrance Width (m)',
#  'Channel Depth (m)',
#  'Anchorage Depth (m)',
#  'Cargo Pier Depth (m)',
#  'Oil Terminal Depth (m)',
#  'Liquified Natural Gas Terminal Depth (m)',
#  'Maximum Vessel Length (m)',
#  'Maximum Vessel Beam (m)',
#  'Maximum Vessel Draft (m)',
#  'Offshore Maximum Vessel Length (m)',
#  'Offshore Maximum Vessel Beam (m)',
#  'Offshore Maximum Vessel Draft (m)',
#  'Harbor Size',
#  'Harbor Type',
#  'Harbor Use',
#  'Shelter Afforded',
#  'Entrance Restriction - Tide',
#  'Entrance Restriction - Heavy Swell',
#  'Entrance Restriction - Ice',
#  'Entrance Restriction - Other',
#  'Overhead Limits',
#  'Underkeel Clearance Management System',
#  'Good Holding Ground',
#  'Turning Area',
#  'Port Security',
#  'Estimated Time of Arrival Message',
#  'Quarantine - Pratique',
#  'Quarantine - Sanitation',
#  'Quarantine - Other',
#  'Traffic Separation Scheme',
#  'Vessel Traffic Service',
#  'First Port of Entry',
#  'US Representative',
#  'Pilotage - Compulsory',
#  'Pilotage - Available',
#  'Pilotage - Local Assistance',
#  'Pilotage - Advisable',
#  'Tugs - Salvage',
#  'Tugs - Assistance',
#  'Communications - Telephone',
#  'Communications - Telefax',
#  'Communications - Radio',
#  'Communications - Radiotelephone',
#  'Communications - Airport',
#  'Communications - Rail',
#  'Search and Rescue',
#  'NAVAREA',
#  'Facilities - Wharves',
#  'Facilities - Anchorage',
#  'Facilities - Dangerous Cargo Anchorage',
#  'Facilities - Med Mooring',
#  'Facilities - Beach Mooring',
#  'Facilities - Ice Mooring',
#  'Facilities - Ro-Ro',
#  'Facilities - Solid Bulk',
#  'Facilities - Liquid Bulk',
#  'Facilities - Container',
#  'Facilities - Breakbulk',
#  'Facilities - Oil Terminal',
#  'Facilities - LNG Terminal',
#  'Facilities - Other',
#  'Medical Facilities',
#  'Garbage Disposal',
#  'Chemical Holding Tank Disposal',
#  'Degaussing',
#  'Dirty Ballast Disposal',
#  'Cranes - Fixed',
#  'Cranes - Mobile',
#  'Cranes - Floating',
#  'Cranes Container',
#  'Lifts - 100+ Tons',
#  'Lifts - 50-100 Tons',
#  'Lifts - 25-49 Tons',
#  'Lifts - 0-24 Tons',
#  'Services - Longshoremen',
#  'Services - Electricity',
#  'Services -Steam',
#  'Services - Navigation Equipment',
#  'Services - Electrical Repair',
#  'Services - Ice Breaking',
#  'Services -Diving',
#  'Supplies - Provisions',
#  'Supplies - Potable Water',
#  'Supplies - Fuel Oil',
#  'Supplies - Diesel Oil',
#  'Supplies - Aviation Fuel',
#  'Supplies - Deck',
#  'Supplies - Engine',
#  'Repairs',
#  'Dry Dock',
#  'Railway',
#  'Latitude',
#  'Longitude']

# %% [markdown]
# Doing some preprocessing:

# %%
#rename
infoseaports.rename(columns={'Main Port Name':'portName', 'Country Code':'countryCode'},inplace=True)

#keep few columns
infoseaports=infoseaports.loc[:,['portName', 'countryCode','Latitude', 'Longitude']]

# we have now
infoseaports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3801 entries, 0 to 3800
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   portName     3801 non-null   object
#  1   countryCode  3801 non-null   object
#  2   Latitude     3801 non-null   float64
#  3   Longitude    3801 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 118.9+ KB

# %%
infoseaports.head()
# Out:
#             portName    countryCode   Latitude  Longitude
# 0             Maurer  United States  40.533333 -74.250000
# 1            Iharana     Madagascar -13.350000  50.000000
# 2            Andoany     Madagascar -13.400000  48.300000
# 3        Chake Chake       Tanzania  -5.250000  39.766667
# 4  Mjimwema Terminal       Tanzania  -6.816667  39.366667

# %% [markdown]
# Turning the points into projected spatial object (GDF of points)

# %%
#spatial points (unprojected)
seaports=gpd.GeoDataFrame(data=infoseaports.copy(),
                           geometry=gpd.points_from_xy(infoseaports.Longitude,
                                                       infoseaports.Latitude),
                          crs=4326)

# keep Russia
seaports_ru=seaports[seaports['countryCode']=='Russia'].copy()

# reset indexes
seaports_ru.reset_index(drop=True, inplace=True)

# reprojecting
seaports_ru_3576=seaports_ru.to_crs(3576) # projected crs

# %%
seaports_ru_3576.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   portName     67 non-null     object
#  1   countryCode  67 non-null     object
#  2   Latitude     67 non-null     float64
#  3   Longitude    67 non-null     float64
#  4   geometry     67 non-null     geometry
# dtypes: float64(2), geometry(1), object(2)
# memory usage: 2.7+ KB

# %% [markdown]
# Plotting seaports along with the large airports:

# %%
airports.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1651 entries, 0 to 1650
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1651 non-null   object
#  1   kind           1651 non-null   object
#  2   latitude_deg   1651 non-null   float64
#  3   longitude_deg  1651 non-null   float64
#  4   elevation_ft   1034 non-null   float64
#  5   region_name    1651 non-null   object
#  6   municipality   1536 non-null   object
#  7   geometry       1651 non-null   geometry
# dtypes: float64(3), geometry(1), object(4)
# memory usage: 103.3+ KB

# %%
# subsetting
largeAirports=airports[airports['kind']=='large_airport'] #can't use "airports.type"
largeAirports.reset_index(drop=True, inplace=True)

#plotting
base=largeAirports.plot(color='red',marker="^")
seaports_ru_3576.plot(ax=base,alpha=0.5,markersize=3)
# Out:
# <Axes: >

# %% [markdown]
# #Exercise 1 (Distance between two points)

# %% [markdown]
# 1. Use two maps of points from your country.
#
# 2. Compute the distance matrix for both maps.
#
# 3. Select one row of the distance matrix, and plot the two points with the minimal distance on top of the country of your choosing.

# %%
seaports_ru_3576.head()
# Out:
#            portName countryCode   Latitude   Longitude  \
# 0     Bukhta Vanino      Russia  49.083333  140.283333
# 1  Sovetskaya Gavan      Russia  48.973611  140.268056
# 2           Lazarev      Russia  52.216667  141.516667
# 3         De Kastri      Russia  51.466667  140.783333
# 4      Novorossiysk      Russia  44.716667   37.783333
#
#                             geometry
# 0   POINT (3435999.476 -2854310.567)
# 1   POINT (3444029.436 -2862533.492)
# 2   POINT (3239715.833 -2575447.993)
# 3   POINT (3267591.924 -2666566.103)
# 4  POINT (-3887184.998 -3013399.055)

# %%
largeAirports.head()
# Out:
#                                name           kind  latitude_deg  \
# 0  Domodedovo International Airport  large_airport     55.408798
# 1                   Pulkovo Airport  large_airport     59.800301
# 2     Vnukovo International Airport  large_airport     55.591499
# 3       Sochi International Airport  large_airport     43.449902
# 4    Novosibirsk Tolmachevo Airport  large_airport     55.019756
#
#    longitude_deg  elevation_ft              region_name    municipality  \
# 0      37.906300         588.0            Moscow Oblast          Moscow
# 1      30.262501          78.0  Saint Petersburg (city)  St. Petersburg
# 2      37.261501         685.0            Moscow (city)          Moscow
# 3      39.956600          89.0           Krasnodar Krai           Sochi
# 4      82.618675         365.0       Novosibirsk Oblast     Novosibirsk
#
#                             geometry
# 0  POINT (-2999019.609 -2335202.716)
# 1  POINT (-2877333.690 -1678852.818)
# 2  POINT (-3009648.144 -2289543.230)
# 3  POINT (-3869472.854 -3241881.698)
# 4   POINT (-493628.256 -3810450.645)

# %% [markdown]
# Let's compute all possible distances between those GDFs

# %%
seaports_ru_3576.set_index('portName').geometry.apply\
(lambda g: largeAirports.set_index('name').geometry.distance(g)/1000)
# Out:
# name              Domodedovo International Airport  Pulkovo Airport  \
# portName
# Bukhta Vanino                          6455.923139      6421.828133
# Sovetskaya Gavan                       6464.592697      6431.230963
# Lazarev                                6243.359489      6182.408736
# De Kastri                              6275.366268      6223.800152
# Novorossiysk                           1117.491849      1673.563062
# ...                                            ...              ...
# Shakhtersk                             6527.934940      6481.213908
# Poronaysk                              6570.188807      6515.955069
# Uglegorsk                              6533.639372      6487.608422
# Nikol Skoye                            6854.754046      6629.536376
# Vladivostok                            6554.810827      6614.909703
#
# name              Vnukovo International Airport  Sochi International Airport  \
# portName
# Bukhta Vanino                       6470.342756                  7315.745850
# Sovetskaya Gavan                    6479.064141                  7323.333995
# Lazarev                             6255.900546                  7140.356971
# De Kastri                           6288.552227                  7160.215197
# Novorossiysk                        1137.557993                   229.168144
# ...                                         ...                          ...
# Shakhtersk                          6541.533091                  7402.771904
# Poronaysk                           6583.295370                  7453.872155
# Uglegorsk                           6547.285726                  7407.515515
# Nikol Skoye                         6855.928948                  7924.734239
# Vladivostok                         6575.403087                  7283.367278
#
# name              Novosibirsk Tolmachevo Airport  Koltsovo Airport  \
# portName
# Bukhta Vanino                        4044.277187       5231.893274
# Sovetskaya Gavan                     4050.147532       5239.379710
# Lazarev                              3932.313523       5062.499630
# De Kastri                            3931.316458       5079.901028
# Novorossiysk                         3485.902838       2110.069928
# ...                                          ...               ...
# Shakhtersk                           4150.188766       5320.514439
# Poronaysk                            4213.024654       5372.862279
# Uglegorsk                            4153.367369       5325.123446
# Nikol Skoye                          5097.537488       5943.880651
# Vladivostok                          3887.418097       5212.046662
#
# name              Vladivostok International Airport  \
# portName
# Bukhta Vanino                            893.546090
# Sovetskaya Gavan                         885.776665
# Lazarev                                 1181.032157
# De Kastri                               1087.208968
# Novorossiysk                            7315.190470
# ...                                             ...
# Shakhtersk                              1013.824870
# Poronaysk                               1088.706966
# Uglegorsk                               1007.160045
# Nikol Skoye                             2838.634738
# Vladivostok                               37.245523
#
# name              Kazan International Airport  Kurumoch International Airport  \
# portName
# Bukhta Vanino                     5901.985698                     6004.142637
# Sovetskaya Gavan                  5910.006760                     6011.872834
# Lazarev                           5713.025342                     5825.195988
# De Kastri                         5736.994955                     5845.919130
# Novorossiysk                      1428.954804                     1324.422671
# ...                                       ...                             ...
# Shakhtersk                        5983.576349                     6089.558369
# Poronaysk                         6031.623836                     6139.865456
# Uglegorsk                         5988.678491                     6094.403168
# Nikol Skoye                       6472.501249                     6630.893230
# Vladivostok                       5931.316305                     6000.015707
#
# name              Krasnoyarsk International Airport  \
# portName
# Bukhta Vanino                           3385.757903
# Sovetskaya Gavan                        3391.445083
# Lazarev                                 3282.519454
# De Kastri                               3278.375646
# Novorossiysk                            4109.468810
# ...                                             ...
# Shakhtersk                              3493.498358
# Poronaysk                               3557.583389
# Uglegorsk                               3496.488888
# Nikol Skoye                             4513.309900
# Vladivostok                             3232.652454
#
# name              Ufa International Airport  Platov International Airport  \
# portName
# Bukhta Vanino                   5631.047430                   6989.282865
# Sovetskaya Gavan                5638.531182                   6997.177292
# Lazarev                         5461.116639                   6803.606818
# De Kastri                       5478.823890                   6826.742054
# Novorossiysk                    1716.741863                    337.360812
# ...                                     ...                           ...
# Shakhtersk                      5719.618327                   7072.400726
# Poronaysk                       5771.863576                   7121.202580
# Uglegorsk                       5724.236093                   7077.411327
# Nikol Skoye                     6323.663557                   7544.540970
# Vladivostok                     5605.082502                   6993.177308
#
# name              Zhukovsky International Airport  \
# portName
# Bukhta Vanino                         6433.692148
# Sovetskaya Gavan                      6442.360008
# Lazarev                               6221.209775
# De Kastri                             6253.184393
# Novorossiysk                          1133.153596
# ...                                           ...
# Shakhtersk                            6505.734599
# Poronaysk                             6548.010288
# Uglegorsk                             6511.437021
# Nikol Skoye                           6833.854531
# Vladivostok                           6532.597421
#
# name              Gagarin International Airport  Lipetsk Air Base
# portName
# Bukhta Vanino                       6341.043796       6602.843324
# Sovetskaya Gavan                    6348.856523       6611.187018
# Lazarev                             6158.842006       6401.769327
# De Kastri                           6180.707209       6429.922219
# Novorossiysk                         984.466118        834.018877
# ...                                         ...               ...
# Shakhtersk                          6425.333952       6679.762680
# Poronaysk                           6474.920112       6724.918144
# Uglegorsk                           6430.259501       6685.171342
# Nikol Skoye                         6936.939528       7072.637158
# Vladivostok                         6342.170228       6661.481965
#
# [67 rows x 15 columns]

# %%
#Reording previous output
seaports_ru_3576.set_index('portName').geometry.apply\
(lambda g: largeAirports.set_index('name').geometry.distance(g)/1000).sort_index(axis=0).sort_index(axis=1)
# Out:
# name                         Domodedovo International Airport  \
# portName
# Adler                                             1258.344216
# Aleksandrovsk -Sakhalinskiy                       6382.069669
# Anapa                                             1101.248805
# Arkhangels'k                                       992.548097
# Azov                                               879.103067
# ...                                                       ...
# Vladivostok                                       6554.810827
# Vostochnyy                                        6645.816719
# Vyborg                                             797.577309
# Yeysk                                              910.205521
# Zarubino                                          6552.770408
#
# name                         Gagarin International Airport  \
# portName
# Adler                                           993.404835
# Aleksandrovsk -Sakhalinskiy                    6291.864803
# Anapa                                           996.616391
# Arkhangels'k                                   1413.192551
# Azov                                            708.575173
# ...                                                    ...
# Vladivostok                                    6342.170228
# Vostochnyy                                     6439.444895
# Vyborg                                         1470.679184
# Yeysk                                           802.914983
# Zarubino                                       6331.279836
#
# name                         Kazan International Airport  Koltsovo Airport  \
# portName
# Adler                                        1455.664994       2087.768179
# Aleksandrovsk -Sakhalinskiy                  5847.333874       5192.537227
# Anapa                                        1435.974609       2124.846341
# Arkhangels'k                                 1081.927641       1408.319432
# Azov                                         1147.828378       1838.221406
# ...                                                  ...               ...
# Vladivostok                                  5931.316305       5212.046662
# Vostochnyy                                   6026.561464       5309.746629
# Vyborg                                       1360.701656       1946.199202
# Yeysk                                        1233.751564       1933.616785
# Zarubino                                     5923.520760       5200.707695
#
# name                         Krasnoyarsk International Airport  \
# portName
# Adler                                              4061.679718
# Aleksandrovsk -Sakhalinskiy                        3394.705933
# Anapa                                              4127.518039
# Arkhangels'k                                       2977.167323
# Azov                                               3844.376794
# ...                                                        ...
# Vladivostok                                        3232.652454
# Vostochnyy                                         3335.166504
# Vyborg                                             3694.095649
# Yeysk                                              3942.103058
# Zarubino                                           3213.848293
#
# name                         Kurumoch International Airport  Lipetsk Air Base  \
# portName
# Adler                                           1318.661088        955.897822
# Aleksandrovsk -Sakhalinskiy                     5957.479669       6538.495802
# Anapa                                           1337.789731        823.684631
# Arkhangels'k                                    1310.935111       1276.485043
# Azov                                            1050.331906        578.247887
# ...                                                     ...               ...
# Vladivostok                                     6000.015707       6661.481965
# Vostochnyy                                      6097.386611       6755.309615
# Vyborg                                          1542.628474       1096.756976
# Yeysk                                           1145.169329        622.749905
# Zarubino                                        5989.032404       6655.591883
#
# name                         Novosibirsk Tolmachevo Airport  \
# portName
# Adler                                           3426.047120
# Aleksandrovsk -Sakhalinskiy                     4047.468209
# Anapa                                           3506.274861
# Arkhangels'k                                    2576.015699
# Azov                                            3227.383939
# ...                                                     ...
# Vladivostok                                     3887.418097
# Vostochnyy                                      3991.113394
# Vyborg                                          3250.484351
# Yeysk                                           3327.047589
# Zarubino                                        3866.080632
#
# name                         Platov International Airport  Pulkovo Airport  \
# portName
# Adler                                          417.653987      1852.315255
# Aleksandrovsk -Sakhalinskiy                   6937.436101      6325.003729
# Anapa                                          345.723224      1646.847327
# Arkhangels'k                                  1812.736744       749.716182
# Azov                                            57.059456      1482.472308
# ...                                                   ...              ...
# Vladivostok                                   6993.177308      6614.909703
# Vostochnyy                                    7090.645238      6698.829979
# Vyborg                                        1589.410259       131.308072
# Yeysk                                          156.418955      1486.170338
# Zarubino                                      6981.900550      6621.599287
#
# name                         Sochi International Airport  \
# portName
# Adler                                           2.657755
# Aleksandrovsk -Sakhalinskiy                  7272.107035
# Anapa                                         272.108998
# Arkhangels'k                                 2228.618472
# Azov                                          377.786449
# ...                                                  ...
# Vladivostok                                  7283.367278
# Vostochnyy                                   7383.072547
# Vyborg                                       1979.391876
# Yeysk                                         366.643294
# Zarubino                                     7268.492929
#
# name                         Ufa International Airport  \
# portName
# Adler                                      1689.128387
# Aleksandrovsk -Sakhalinskiy                5591.378346
# Anapa                                      1733.051547
# Arkhangels'k                               1389.781151
# Azov                                       1448.371546
# ...                                                ...
# Vladivostok                                5605.082502
# Vostochnyy                                 5703.466606
# Vyborg                                     1789.097673
# Yeysk                                      1545.676215
# Zarubino                                   5592.588168
#
# name                         Vladivostok International Airport  \
# portName
# Adler                                              7280.798954
# Aleksandrovsk -Sakhalinskiy                        1121.484575
# Anapa                                              7330.287231
# Arkhangels'k                                       5856.421374
# Azov                                               7043.472069
# ...                                                        ...
# Vladivostok                                          37.245523
# Vostochnyy                                          105.973199
# Vyborg                                             6599.884378
# Yeysk                                              7138.089173
# Zarubino                                            122.471550
#
# name                         Vnukovo International Airport  \
# portName
# Adler                                          1284.453852
# Aleksandrovsk -Sakhalinskiy                    6394.922213
# Anapa                                          1119.786682
# Arkhangels'k                                    979.587361
# Azov                                            905.453725
# ...                                                    ...
# Vladivostok                                    6575.403087
# Vostochnyy                                     6665.984779
# Vyborg                                          755.362152
# Yeysk                                           932.188016
# Zarubino                                       6573.916154
#
# name                         Zhukovsky International Airport
# portName
# Adler                                            1271.429977
# Aleksandrovsk -Sakhalinskiy                      6359.903702
# Anapa                                            1117.473960
# Arkhangels'k                                      975.292782
# Azov                                              892.249031
# ...                                                      ...
# Vladivostok                                      6532.597421
# Vostochnyy                                       6623.587265
# Vyborg                                            796.505118
# Yeysk                                             925.220056
# Zarubino                                         6530.581566
#
# [67 rows x 15 columns]

# %%
# Saving it

distanceMatrixKM_sea_air= seaports_ru_3576.set_index('portName').geometry.apply\
                          (lambda g: largeAirports.set_index('name').geometry.distance(g)/1000).\
                          sort_index(axis=0).sort_index(axis=1)

# %% [markdown]
# *Select one row of the distance matrix, and plot the two points with the minimal distance on top of the country of your choosing.*

# %%
anapa_distances = distanceMatrixKM_sea_air.loc['Anapa']
closest_airport = anapa_distances.idxmin()
min_distance = anapa_distances.min()

# %%
seaports = seaports_ru_3576.set_index('portName')
airports = largeAirports.set_index('name')
ru = country[country.COUNTRY=='Russia']

# %%
base = ru.plot(facecolor="greenyellow", edgecolor='black', linewidth=0.4,figsize=(5,5))
seaports.loc[['Anapa']].plot(ax=base, color='blue', markersize=15, label='Anapa Port')
airports.loc[[closest_airport]].plot(ax=base, color='red', markersize=15, label=closest_airport)
# Out:
# <Axes: >

# %% [markdown]
# #Exercise 2 (Distance between line and point)

# %% [markdown]
# 1. Use a map of points and a map of lines from your country.
#
# 2. Compute the distance matrix for both.
#
# 3. Select one line of the distance matrix, and plot the closests and the farthest point to that line.

# %% [markdown]
# Let's take a look at the rivers we have:

# %%
rivers.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NAME      18 non-null     object
#  1   SYSTEM    6 non-null      object
#  2   geometry  18 non-null     geometry
# dtypes: geometry(1), object(2)
# memory usage: 560.0+ bytes

# %%
distanceMatrixKM_riv_air=rivers.set_index('NAME').geometry.apply\
(lambda g: largeAirports.set_index('name').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)
distanceMatrixKM_riv_air
# Out:
# name     Domodedovo International Airport  Gagarin International Airport  \
# NAME
# Aldan                         4864.775730                    4829.445667
# Amur                          5200.651184                    5001.416491
# Angara                        3401.368853                    3135.261274
# Dnieper                        253.343981                     938.860370
# Don                            141.966632                     288.423010
# Irtysh                        1937.617920                    1632.665142
# Kama                           775.042339                     443.286680
# Kolyma                        5380.146095                    5489.126032
# Lena                          4167.539560                    3931.671386
# Neva                           607.016906                    1255.579445
# Ob                            1791.325175                    1686.375672
# Pechora                       1335.903340                    1280.544352
# Suir                           600.495601                    1174.037144
# Tobol                         1756.111237                    1296.397408
# Ural                          1098.314466                     465.571104
# Vilyuy                        3636.781868                    3560.515634
# Volga                          153.893727                      13.700517
# Yenisey                       2716.188582                    2753.010208
#
# name     Kazan International Airport  Koltsovo Airport  \
# NAME
# Aldan                    4373.764584       3754.637276
# Amur                     4584.448877       3872.414295
# Angara                   2737.058361       2004.488333
# Dnieper                   994.934387       1714.949394
# Don                       708.561696       1408.059578
# Irtysh                   1239.133031        502.254364
# Kama                       42.762900        305.898685
# Kolyma                   5024.270223       4514.575545
# Lena                     3524.550561       2801.423113
# Neva                     1122.630848       1697.299076
# Ob                       1229.657099        667.471590
# Pechora                   815.797968        571.207648
# Suir                      971.710891       1504.837230
# Tobol                    1005.658797        330.549405
# Ural                      489.216714        225.887053
# Vilyuy                   3108.929661       2491.930020
# Volga                       0.119222        747.900600
# Yenisey                  2288.392825       1674.927862
#
# name     Krasnoyarsk International Airport  Kurumoch International Airport  \
# NAME
# Aldan                          1960.448250                     4504.217897
# Amur                           1919.113849                     4659.501073
# Angara                          216.147267                     2792.997677
# Dnieper                        3647.787448                     1109.925142
# Don                            3407.227397                      625.758201
# Irtysh                         1127.669123                     1290.439145
# Kama                           2188.383583                      189.269343
# Kolyma                         3073.780419                     5188.079610
# Lena                            849.219231                     3589.477626
# Neva                           3466.381301                     1312.207510
# Ob                              510.944791                     1367.735847
# Pechora                        2018.052943                      988.848290
# Suir                           3252.696847                     1177.304288
# Tobol                          1519.717546                      968.536540
# Ural                           2150.469490                      270.298183
# Vilyuy                         1230.810948                     3232.082428
# Volga                          2756.929078                        2.781843
# Yenisey                          16.309138                     2438.096728
#
# name     Lipetsk Air Base  Novosibirsk Tolmachevo Airport  \
# NAME
# Aldan         5039.008818                     2611.031144
# Amur          5311.110565                     2567.876647
# Angara        3476.557687                      754.950183
# Dnieper        473.650576                     3123.421043
# Don             23.950111                     2787.415518
# Irtysh        1982.567421                      514.075959
# Kama           751.405599                     1669.537584
# Kolyma        5604.502182                     3658.412326
# Lena          4259.194548                     1508.652588
# Neva           916.915536                     3010.580128
# Ob            1918.301936                       31.149404
# Pechora       1470.602489                     1571.881323
# Suir           909.018179                     2804.363419
# Tobol         1723.154263                      967.918362
# Ural           952.973483                     1535.552791
# Vilyuy        3791.743023                     1667.767794
# Volga          465.182178                     2178.105045
# Yenisey       2907.111209                      573.227369
#
# name     Platov International Airport  Pulkovo Airport  \
# NAME
# Aldan                     5464.693068      4777.327416
# Amur                      5652.779562      5264.608868
# Angara                    3785.273457      3573.500401
# Dnieper                    913.339487       471.919094
# Don                         28.118529       799.007169
# Irtysh                    2283.465177      2168.562561
# Kama                      1078.998590      1291.832414
# Kolyma                    6085.485151      5130.966913
# Lena                      4582.582858      4067.617571
# Neva                      1433.780395        12.398150
# Ob                        2321.048790      1919.804627
# Pechora                   1896.140120      1306.470595
# Suir                      1444.551200       176.127848
# Tobol                     1926.078822      2185.200030
# Ural                      1055.087481      1694.223446
# Vilyuy                    4200.566591      3620.359234
# Volga                      398.658091       308.071154
# Yenisey                   3363.237146      2633.499707
#
# name     Sochi International Airport  Ufa International Airport  \
# NAME
# Aldan                    5818.833079                4153.784026
# Amur                     5949.350677                4267.189628
# Angara                   4073.551535                2395.381975
# Dnieper                  1297.539945                1449.816126
# Don                       383.105009                1013.768215
# Irtysh                   2583.180502                 897.385607
# Kama                     1433.921022                 196.760245
# Kolyma                   6472.175702                4888.972927
# Lena                     4875.266657                3194.729323
# Neva                     1832.690601                1544.301761
# Ob                       2677.012151                1053.577328
# Pechora                  2268.221156                 777.082102
# Suir                     1857.230930                1373.909532
# Tobol                    2180.952648                 564.499781
# Ural                     1308.814936                 237.107457
# Vilyuy                   4547.900094                2885.434639
# Volga                     668.043605                 400.637403
# Yenisey                  3740.548502                2072.886048
#
# name     Vladivostok International Airport  Vnukovo International Airport  \
# NAME
# Aldan                          1497.011575                    4874.867508
# Amur                            451.379540                    5220.971018
# Angara                         2062.952729                    3427.247942
# Dnieper                        6705.479727                     208.070535
# Don                            6597.661299                     176.815968
# Irtysh                         4351.427825                    1968.596526
# Kama                           5299.507884                     816.207450
# Kolyma                         2135.435295                    5380.165447
# Lena                           1895.414150                    4190.853334
# Neva                           6397.169568                     569.784201
# Ob                             3668.967667                    1811.681592
# Pechora                        5054.863938                    1356.008838
# Suir                           6166.554361                     575.163761
# Tobol                          4703.254422                    1795.047109
# Ural                           5362.329800                    1144.484880
# Vilyuy                         2205.932291                    3650.706875
# Volga                          5914.250659                     119.852800
# Yenisey                        2770.144082                    2724.264638
#
# name     Zhukovsky International Airport
# NAME
# Aldan                        4842.791739
# Amur                         5178.425904
# Angara                       3379.555651
# Dnieper                       266.771240
# Don                           153.208633
# Irtysh                       1916.613553
# Kama                          757.887304
# Kolyma                       5359.452598
# Lena                         4145.481971
# Neva                          601.796305
# Ob                           1769.090179
# Pechora                      1313.665043
# Suir                          588.356011
# Tobol                        1737.741519
# Ural                         1086.782779
# Vilyuy                       3614.573364
# Volga                         149.462199
# Yenisey                      2694.403865

# %%
# !pip install mapclassify
# Out:
# Collecting mapclassify
#   Downloading mapclassify-2.7.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 kB 963.4 kB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (3.3)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.25.2)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.2.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->mapclassify) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->mapclassify) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas!=1.5.0,>=1.4->mapclassify) (1.16.0)
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.7.0

# %%
ob_river = distanceMatrixKM_riv_air.loc['Ob']
min = ob_river.idxmin()
max = ob_river.idxmax()

# %%
ob = rivers[rivers['NAME'] == 'Ob'].copy()
closest_airport = largeAirports[largeAirports['name'] == min].copy()
farthest_airport = largeAirports[largeAirports['name'] == max].copy()

# %%
# Plotting the river and the closest and farthest airports
base=ob.explore(color='blue')
closest_airport.explore(m=base, color='red', marker_kwds=dict(radius=5))
farthest_airport.explore(m=base, color='green', marker_kwds=dict(radius=5))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69c536b74eb92164c23b6614f857bfe6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69c536b74eb92164c23b6614f857bfe6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69c536b74eb92164c23b6614f857bfe6 = L.map(
#                 &quot;map_69c536b74eb92164c23b6614f857bfe6&quot;,
#                 {
#                     center: [58.17489051604814, 76.10771942138672],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_69c536b74eb92164c23b6614f857bfe6);
#
#
#
#
#
#             var tile_layer_d41d1891a66147a2f97031213f629c52 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_69c536b74eb92164c23b6614f857bfe6);
#
#
#             map_69c536b74eb92164c23b6614f857bfe6.fitBounds(
#                 [[49.65840530076611, 65.26892852783203], [66.69137573133017, 86.9465103149414]],
#                 {}
#             );
#
#
#         function geo_json_3c843f2426b5cdd93776cb0d6093351f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3c843f2426b5cdd93776cb0d6093351f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_3c843f2426b5cdd93776cb0d6093351f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_3c843f2426b5cdd93776cb0d6093351f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3c843f2426b5cdd93776cb0d6093351f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_3c843f2426b5cdd93776cb0d6093351f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3c843f2426b5cdd93776cb0d6093351f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3c843f2426b5cdd93776cb0d6093351f = L.geoJson(null, {
#                 onEachFeature: geo_json_3

# %% [markdown]
# Now, let's focus on the rivers that belong to a system:

# %%
rivers
# Out:
#        NAME SYSTEM                                           geometry
# 0       Don   None  LINESTRING (-3603827.117 -2965834.980, -354442...
# 1      Ural   None  MULTILINESTRING ((-2564645.559 -3343971.198, -...
# 2   Dnieper   None  LINESTRING (-3106755.888 -2091252.001, -311286...
# 3     Volga   None  LINESTRING (-3024254.968 -1949633.124, -304789...
# 4      Amur   None  MULTILINESTRING ((2076412.934 -3891300.095, 20...
# 5    Irtysh     Ob  LINESTRING (-1007373.782 -3828879.610, -102079...
# 6     Tobol     Ob  LINESTRING (-1706906.012 -3524475.237, -170173...
# 7    Angara   None  MULTILINESTRING ((1084472.706 -4025265.396, 10...
# 8        Ob     Ob  MULTILINESTRING ((-1136717.208 -2972266.070, -...
# 9     Aldan   Lena  LINESTRING (2062501.612 -3057003.723, 2011720....
# 10  Yenisey   None  MULTILINESTRING ((637756.065 -4050854.493, 584...
# 11     Kama   None  LINESTRING (-2057072.686 -2828765.853, -204765...
# 12     Neva   None  MULTILINESTRING ((-2828633.894 -1716872.710, -...
# 13     Suir   None  MULTILINESTRING ((-2614529.572 -1833514.376, -...
# 14  Pechora   None  LINESTRING (-1548828.072 -2645390.886, -156992...
# 15     Lena   Lena  MULTILINESTRING ((1865098.500 -2255215.698, 18...
# 16   Vilyuy   Lena  LINESTRING (1686760.007 -2268614.350, 1696838....
# 17   Kolyma   None  LINESTRING (2198322.970 -754373.634, 2245534.0...

# %%
rivers[~rivers.SYSTEM.isna()]
# Out:
#       NAME SYSTEM                                           geometry
# 5   Irtysh     Ob  LINESTRING (-1007373.782 -3828879.610, -102079...
# 6    Tobol     Ob  LINESTRING (-1706906.012 -3524475.237, -170173...
# 8       Ob     Ob  MULTILINESTRING ((-1136717.208 -2972266.070, -...
# 9    Aldan   Lena  LINESTRING (2062501.612 -3057003.723, 2011720....
# 15    Lena   Lena  MULTILINESTRING ((1865098.500 -2255215.698, 18...
# 16  Vilyuy   Lena  LINESTRING (1686760.007 -2268614.350, 1696838....

# %% [markdown]
# Let's dissolve the ones that belong to a system into a multiline:

# %%
systems=rivers.dissolve(by='SYSTEM')
systems
# Out:
#                                                  geometry    NAME
# SYSTEM
# Lena    MULTILINESTRING ((2062501.612 -3057003.723, 20...   Aldan
# Ob      MULTILINESTRING ((-1007373.782 -3828879.610, -...  Irtysh

# %% [markdown]
# Let's do some basic formatting:

# %%
# format the GDF:

systems.reset_index(drop=False,inplace=True)
systems.drop(columns='NAME',inplace=True)

# we have
systems
# Out:
#   SYSTEM                                           geometry
# 0   Lena  MULTILINESTRING ((2062501.612 -3057003.723, 20...
# 1     Ob  MULTILINESTRING ((-1007373.782 -3828879.610, -...

# %% [markdown]
# Another distance matrix:

# %%
distanceMatrixKM_sys_air=systems.set_index('SYSTEM').geometry.apply\
(lambda g: largeAirports.set_index('name').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)

distanceMatrixKM_sys_air
# Out:
# name    Domodedovo International Airport  Gagarin International Airport  \
# SYSTEM
# Lena                         3636.781868                    3560.515634
# Ob                           1756.111237                    1296.397408
#
# name    Kazan International Airport  Koltsovo Airport  \
# SYSTEM
# Lena                    3108.929661       2491.930020
# Ob                      1005.658797        330.549405
#
# name    Krasnoyarsk International Airport  Kurumoch International Airport  \
# SYSTEM
# Lena                           849.219231                     3232.082428
# Ob                             510.944791                      968.536540
#
# name    Lipetsk Air Base  Novosibirsk Tolmachevo Airport  \
# SYSTEM
# Lena         3791.743023                     1508.652588
# Ob           1723.154263                       31.149404
#
# name    Platov International Airport  Pulkovo Airport  \
# SYSTEM
# Lena                     4200.566591      3620.359234
# Ob                       1926.078822      1919.804627
#
# name    Sochi International Airport  Ufa International Airport  \
# SYSTEM
# Lena                    4547.900094                2885.434639
# Ob                      2180.952648                 564.499781
#
# name    Vladivostok International Airport  Vnukovo International Airport  \
# SYSTEM
# Lena                          1497.011575                    3650.706875
# Ob                            3668.967667                    1795.047109
#
# name    Zhukovsky International Airport
# SYSTEM
# Lena                        3614.573364
# Ob                          1737.741519

# %% [markdown]
# Let's get all the minimun distances:

# %%
mins=distanceMatrixKM_sys_air.idxmin(axis="columns") # same as axis=1
mins
# Out:
# SYSTEM
# Lena    Krasnoyarsk International Airport
# Ob         Novosibirsk Tolmachevo Airport
# dtype: object

# %% [markdown]
# Finally:

# %%
base=systems.explore()
# the closest
largeAirports[largeAirports.name.isin(mins)].explore(m=base,color='red',marker_kwds=dict(radius=10))
# NOT the closest
largeAirports[~largeAirports.name.isin(mins)].explore(m=base,color='blue',marker_kwds=dict(radius=5))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_735be79501b6fd15ba714f6d9e7b8991 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_735be79501b6fd15ba714f6d9e7b8991&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_735be79501b6fd15ba714f6d9e7b8991 = L.map(
#                 &quot;map_735be79501b6fd15ba714f6d9e7b8991&quot;,
#                 {
#                     center: [60.946294782528696, 100.12202480731719],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_735be79501b6fd15ba714f6d9e7b8991);
#
#
#
#
#
#             var tile_layer_2d7a7075d67bd7ac959a108a03ba4674 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_735be79501b6fd15ba714f6d9e7b8991);
#
#
#             map_735be79501b6fd15ba714f6d9e7b8991.fitBounds(
#                 [[49.65840530076611, 64.15905815955624], [72.23418426429127, 136.08499145507812]],
#                 {}
#             );
#
#
#         function geo_json_f76cd8eb8ba995787a91ca25144c38ed_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f76cd8eb8ba995787a91ca25144c38ed_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f76cd8eb8ba995787a91ca25144c38ed_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_f76cd8eb8ba995787a91ca25144c38ed_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f76cd8eb8ba995787a91ca25144c38ed_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_f76cd8eb8ba995787a91ca25144c38ed.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f76cd8eb8ba995787a91ca25144c38ed_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f76cd8eb8ba995787a91ca25144c38ed = L.geoJson(null, {
#                 onEachFeature: geo_json_f76cd8eb8ba995787a91ca25144c38ed_onEachFeature,

# %% [markdown]
# #Exercise 3 (Polygon to point)

# %% [markdown]
# 1. Create a HULL for some set of line map.
#
# 2. Compute the distance matrix between the HULLS and a map of points.
#
# 3. Plot the HULLS and the points. Show the closest and farthest points to the HULL.

# %%
systems.plot()
# Out:
# <Axes: >

# %%
# polygon for each system
systems.convex_hull
# Out:
# 0    POLYGON ((1111476.898 -3800925.630, 1034119.83...
# 1    POLYGON ((-306634.030 -4396234.128, -1706906.0...
# dtype: geometry

# %%
# see them
systems.convex_hull.plot()
# Out:
# <Axes: >

# %% [markdown]
# Now, a GDF for the hulls:

# %%
systems_hulls=systems.convex_hull.to_frame()
systems_hulls['system']=['Lena', 'Ob']
systems_hulls.rename(columns={0:'geometry'},inplace=True)
systems_hulls=systems_hulls.set_geometry('geometry')
systems_hulls.crs="EPSG:3576"
systems_hulls
# Out:
#                                             geometry system
# 0  POLYGON ((1111476.898 -3800925.630, 1034119.83...   Lena
# 1  POLYGON ((-306634.030 -4396234.128, -1706906.0...     Ob

# %% [markdown]
# Next, the distance matrix:

# %%
distanceMatrixKM_sysHull_air=systems_hulls.set_index('system').geometry.apply\
(lambda g: largeAirports.set_index('name').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)

distanceMatrixKM_sysHull_air
# Out:
# name    Domodedovo International Airport  Gagarin International Airport  \
# system
# Lena                         3636.781868                    3560.515634
# Ob                           1705.857116                    1296.397408
#
# name    Kazan International Airport  Koltsovo Airport  \
# system
# Lena                    3108.929661       2491.930020
# Ob                       983.296215        227.907791
#
# name    Krasnoyarsk International Airport  Kurumoch International Airport  \
# system
# Lena                           808.198088                     3232.082428
# Ob                             477.690536                      968.536540
#
# name    Lipetsk Air Base  Novosibirsk Tolmachevo Airport  \
# system
# Lena         3791.743023                     1459.233194
# Ob           1719.937118                        0.000000
#
# name    Platov International Airport  Pulkovo Airport  \
# system
# Lena                     4200.566591      3620.359234
# Ob                       1926.078822      1916.380431
#
# name    Sochi International Airport  Ufa International Airport  \
# system
# Lena                    4547.900094                2885.434639
# Ob                      2180.952648                 563.386598
#
# name    Vladivostok International Airport  Vnukovo International Airport  \
# system
# Lena                          1497.011575                    3650.706875
# Ob                            3668.582499                    1737.220343
#
# name    Zhukovsky International Airport
# system
# Lena                        3614.573364
# Ob                          1684.990679

# %%
ob_system = distanceMatrixKM_sysHull_air.loc['Ob']
min_ob = ob_system.idxmin()
max_ob = ob_system.idxmax()

lena_system = distanceMatrixKM_sysHull_air.loc['Lena']
min_lena = lena_system.idxmin()
max_lena = lena_system.idxmax()

# %%
mins=distanceMatrixKM_sysHull_air.idxmin(axis="columns")
maxs=distanceMatrixKM_sysHull_air.idxmax(axis="columns")

mins, maxs
# Out:
# (system
#  Lena    Krasnoyarsk International Airport
#  Ob         Novosibirsk Tolmachevo Airport
#  dtype: object,
#  system
#  Lena          Sochi International Airport
#  Ob      Vladivostok International Airport
#  dtype: object)

# %%
# plotting
base=systems_hulls.explore()
largeAirports[largeAirports.name.isin(mins)].explore(m=base,color='red',marker_kwds=dict(radius=10))
largeAirports[~largeAirports.name.isin(mins + maxs)].explore(m=base,color='blue',marker_kwds=dict(radius=5))
largeAirports[largeAirports.name.isin(maxs)].explore(m=base,color='green',marker_kwds=dict(radius=10))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_489ba31f3298e9ac4699b4698a8e96a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_489ba31f3298e9ac4699b4698a8e96a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_489ba31f3298e9ac4699b4698a8e96a6 = L.map(
#                 &quot;map_489ba31f3298e9ac4699b4698a8e96a6&quot;,
#                 {
#                     center: [60.946294782528696, 100.12202480731719],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_489ba31f3298e9ac4699b4698a8e96a6);
#
#
#
#
#
#             var tile_layer_cf22904585c305f2163aeffa0bd134ec = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_489ba31f3298e9ac4699b4698a8e96a6);
#
#
#             map_489ba31f3298e9ac4699b4698a8e96a6.fitBounds(
#                 [[49.65840530076611, 64.15905815955624], [72.23418426429127, 136.08499145507812]],
#                 {}
#             );
#
#
#         function geo_json_919ead6b39d6ebd1d3f0aabdc29ad402_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_919ead6b39d6ebd1d3f0aabdc29ad402_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_919ead6b39d6ebd1d3f0aabdc29ad402_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_919ead6b39d6ebd1d3f0aabdc29ad402_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_919ead6b39d6ebd1d3f0aabdc29ad402_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_919ead6b39d6ebd1d3f0aabdc29ad402.resetStyle(e.target);
#                     }
#                 },

# %% [markdown]
# #Exercise 4 (Distance using buffers)

# %% [markdown]
# 1. Select a line map and a point one.
#
# 2. Get the buffer for the lines, select a distance.
#
# 3. Keep the points that are within the buffer (you might need to play with differnt distances until you show something interesting).

# %%
minMts=distanceMatrixKM_riv_air.loc['Ob'].min()*1000 # km

#the buffer is a polygon:
rivers[rivers.NAME=='Ob'].buffer(distance = minMts)
# Out:
# 8    POLYGON ((-1237545.684 -2661697.116, -1237367....
# dtype: geometry

# %%
small_airports=airports[airports['kind']=='small_airport']
small_airports.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 0 entries
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   kind           0 non-null      object
#  1   latitude_deg   0 non-null      float64
#  2   longitude_deg  0 non-null      float64
#  3   elevation_ft   0 non-null      float64
#  4   region_name    0 non-null      object
#  5   municipality   0 non-null      object
#  6   geometry       0 non-null      geometry
# dtypes: float64(3), geometry(1), object(3)
# memory usage: 108.0+ bytes

# %%
airports.kind.value_counts()
# Out:
# kind
# large_airport    15
# Name: count, dtype: int64

# %%
# see buffer:
bufferAroundOb=rivers[rivers.NAME=='Ob'].buffer(distance = minMts)
bufferAsBase=bufferAroundOb.explore(color='red')
rivers[rivers.NAME=='Ob'].explore(m=bufferAsBase,color='blue',style_kwds={'weight':0.5})
largeAirports.explore(m=bufferAsBase,color='black')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73efd3e38b856becc9d7e7c4999db6e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73efd3e38b856becc9d7e7c4999db6e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73efd3e38b856becc9d7e7c4999db6e6 = L.map(
#                 &quot;map_73efd3e38b856becc9d7e7c4999db6e6&quot;,
#                 {
#                     center: [58.16821898940037, 76.01387104935043],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_73efd3e38b856becc9d7e7c4999db6e6);
#
#
#
#
#
#             var tile_layer_f88adb95f9896947bf96bd850ea8ca8d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_73efd3e38b856becc9d7e7c4999db6e6);
#
#
#             map_73efd3e38b856becc9d7e7c4999db6e6.fitBounds(
#                 [[49.360039794890845, 64.66995169603506], [66.97639818390991, 87.3577904026658]],
#                 {}
#             );
#
#
#         function geo_json_76a43cf7186d0a5a9d10494b5f4d2a05_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_76a43cf7186d0a5a9d10494b5f4d2a05_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_76a43cf7186d0a5a9d10494b5f4d2a05_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_76a43cf7186d0a5a9d10494b5f4d2a05_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_76a43cf7186d0a5a9d10494b5f4d2a05_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_76a43cf7186d0a5a9d10494b5f4d2a05.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_76a43cf7186d0a5a9d10494b5f4d2a05_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_76a43cf7186d0a5a9d10494b5f4d2a05 = L.geoJson(null, {
#                 onEachFeature: geo_json_76

# %%
# see buffer:
bufferAroundOb=rivers[rivers.NAME=='Ob'].buffer(distance = minMts*2)
bufferAsBase=bufferAroundOb.explore(color='red', style_kwds={'weight': 3})
rivers[rivers.NAME=='Ob'].explore(m=bufferAsBase,color='blue',style_kwds={'weight':0.5})
largeAirports.explore(m=bufferAsBase,color='black')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6218058dd5c7670bcf72ca3079ca0c36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6218058dd5c7670bcf72ca3079ca0c36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6218058dd5c7670bcf72ca3079ca0c36 = L.map(
#                 &quot;map_6218058dd5c7670bcf72ca3079ca0c36&quot;,
#                 {
#                     center: [58.161316608633534, 75.91989683060845],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6218058dd5c7670bcf72ca3079ca0c36);
#
#
#
#
#
#             var tile_layer_53e671daad8dae921b4aee8034c2ad49 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6218058dd5c7670bcf72ca3079ca0c36);
#
#
#             map_6218058dd5c7670bcf72ca3079ca0c36.fitBounds(
#                 [[49.06136956812186, 64.07092428967212], [67.2612636491452, 87.76886937154477]],
#                 {}
#             );
#
#
#         function geo_json_be6808f474ac0c46920fbd916d29a51a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 3};
#             }
#         }
#         function geo_json_be6808f474ac0c46920fbd916d29a51a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_be6808f474ac0c46920fbd916d29a51a_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_be6808f474ac0c46920fbd916d29a51a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_be6808f474ac0c46920fbd916d29a51a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_be6808f474ac0c46920fbd916d29a51a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_be6808f474ac0c46920fbd916d29a51a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_be6808f474ac0c46920fbd916d29a51a = L.geoJson(null, {
#                 onEachFeature: geo_json_be

# %% [markdown]
# Using the buffer (polygon) to keep the airports that are at that particular distance around the river:

# %%
riversWithinBuffer=largeAirports.clip(mask=bufferAroundOb)
riversWithinBuffer
# Out:
#                              name           kind  latitude_deg  longitude_deg  \
# 4  Novosibirsk Tolmachevo Airport  large_airport     55.019756      82.618675
#
#    elevation_ft         region_name municipality  \
# 4         365.0  Novosibirsk Oblast  Novosibirsk
#
#                            geometry
# 4  POINT (-493628.256 -3810450.645)

# %%
# plotting the airports within buffer
bufferAsBase=bufferAroundOb.explore(color='red')
rivers[rivers.NAME=='Ob'].explore(m=bufferAsBase,color='blue',style_kwds={'weight':0.5})
riversWithinBuffer.explore(m=bufferAsBase,color='black')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c0e9905389ad0162508c5f96003c492 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c0e9905389ad0162508c5f96003c492&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c0e9905389ad0162508c5f96003c492 = L.map(
#                 &quot;map_2c0e9905389ad0162508c5f96003c492&quot;,
#                 {
#                     center: [58.161316608633534, 75.91989683060845],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2c0e9905389ad0162508c5f96003c492);
#
#
#
#
#
#             var tile_layer_775db7710942c347ac3450bb58f8b277 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c0e9905389ad0162508c5f96003c492);
#
#
#             map_2c0e9905389ad0162508c5f96003c492.fitBounds(
#                 [[49.06136956812186, 64.07092428967212], [67.2612636491452, 87.76886937154477]],
#                 {}
#             );
#
#
#         function geo_json_86332f4c9b2fdc149dcbff34f641f339_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_86332f4c9b2fdc149dcbff34f641f339_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_86332f4c9b2fdc149dcbff34f641f339_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_86332f4c9b2fdc149dcbff34f641f339_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_86332f4c9b2fdc149dcbff34f641f339_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_86332f4c9b2fdc149dcbff34f641f339.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_86332f4c9b2fdc149dcbff34f641f339_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_86332f4c9b2fdc149dcbff34f641f339 = L.geoJson(null, {
#                 onEachFeature: geo_json_86

# %%
# minimum of all the minimum by row
distanceMatrixKM_riv_air.min(axis=1).min()
# Out:
# 0.11922216278431494

# %%
# using the previous value
minMinMts_5=5*distanceMatrixKM_riv_air.min(axis=1).min()*1000


allMinBuffer=rivers.buffer(distance = minMinMts_5).explore(color='red')
rivers.explore(m=allMinBuffer,color='blue',style_kwds={'weight':0.5})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0be4bfc0cd7c04c0ec28758401ee63c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0be4bfc0cd7c04c0ec28758401ee63c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0be4bfc0cd7c04c0ec28758401ee63c3 = L.map(
#                 &quot;map_0be4bfc0cd7c04c0ec28758401ee63c3&quot;,
#                 {
#                     center: [59.00050300978484, 95.53573493503997],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0be4bfc0cd7c04c0ec28758401ee63c3);
#
#
#
#
#
#             var tile_layer_9ea0aae6960784247b63999de1196c1b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0be4bfc0cd7c04c0ec28758401ee63c3);
#
#
#             map_0be4bfc0cd7c04c0ec28758401ee63c3.fitBounds(
#                 [[45.76141557089845, 29.996884855188217], [72.23959044867124, 161.0745850148917]],
#                 {}
#             );
#
#
#         function geo_json_4acae593b3cd5a59070653e3baeeb09b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4acae593b3cd5a59070653e3baeeb09b_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4acae593b3cd5a59070653e3baeeb09b_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_4acae593b3cd5a59070653e3baeeb09b_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_4acae593b3cd5a59070653e3baeeb09b_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_4acae593b3cd5a59070653e3baeeb09b.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4acae593b3cd5a59070653e3baeeb09b_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4acae593b3cd5a59070653e3baeeb09b = L.geoJson(null, {
#                 onEachFeature: geo_json_4acae593b3cd5a59070653e3baeeb09b_onEachFeature,
#
#                 style: geo_json_4acae593b3cd5a59070653e3baeeb09b_styler,
#                 pointToLayer: geo_json_4acae593b3cd5a59070653e3baeeb09b_pointToLayer
#         });
#
#         function geo_json_4acae593b3cd5a59070653e3baeeb09b_add (data) {
#             geo_json_4acae593b3cd5a59070653e3baeeb09b
#                 .addData(data)
#                 .addTo(map_0be4bfc0cd7c04c0ec28758401ee63c3);
#         }
#             geo_json_4acae593b3cd5a59070653e3baeeb09b_add({&quot;bbox&quot;: [29.9

# %%
# you see all the buffer polygons:
riversAll_buf=rivers.buffer(distance = minMinMts_5*5)
riversAll_buf
# Out:
# 0     POLYGON ((-3542973.829 -3013693.064, -3475250....
# 1     MULTIPOLYGON (((-2190908.470 -3621985.914, -21...
# 2     POLYGON ((-3110052.330 -2109857.201, -3110163....
# 3     POLYGON ((-3044517.077 -1973217.337, -3026207....
# 4     MULTIPOLYGON (((3164815.855 -3250167.561, 3164...
# 5     POLYGON ((-1023518.900 -3771245.745, -1095378....
# 6     POLYGON ((-1703434.309 -3518432.169, -1703198....
# 7     POLYGON ((949473.752 -3936136.392, 949225.573 ...
# 8     MULTIPOLYGON (((-1164869.849 -2953751.917, -11...
# 9     POLYGON ((2012310.652 -3070188.496, 2012022.41...
# 10    MULTIPOLYGON (((-267599.232 -2199531.050, -267...
# 11    POLYGON ((-2051061.557 -2806614.209, -2059021....
# 12    POLYGON ((-2850624.336 -1715292.535, -2850910....
# 13    POLYGON ((-2648674.583 -1790050.458, -2648393....
# 14    POLYGON ((-1568339.469 -2661197.554, -1568597....
# 15    MULTIPOLYGON (((1210605.047 -1573682.397, 1210...
# 16    POLYGON ((1699451.544 -2285542.711, 1699573.25...
# 17    POLYGON ((2246685.866 -771405.725, 2246955.700...
# dtype: geometry

# %% [markdown]
# Now keep large airports in buffer:

# %%
allRiversWithinBuffs=largeAirports.clip(riversAll_buf)
allRiversWithinBuffs
# Out:
#                              name           kind  latitude_deg  longitude_deg  \
# 8  Kurumoch International Airport  large_airport     53.504902      50.164299
# 7     Kazan International Airport  large_airport     55.606201      49.278702
#
#    elevation_ft            region_name municipality  \
# 8         477.0          Samara Oblast       Samara
# 7         411.0  Republic of Tatarstan        Kazan
#
#                             geometry
# 8  POINT (-2564134.582 -3073673.498)
# 7  POINT (-2465976.887 -2864807.879)

# %%
# simple
base=riversAll_buf.plot(color='blue')
allRiversWithinBuffs.plot(ax=base, color='green', markersize=5)
# Out:
# <Axes: >

# %%
# folium

base=riversAll_buf.explore(color='yellow')
allRiversWithinBuffs.explore(m=base, color='green')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd969d3768e0d8a9d571ca3279174ed9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd969d3768e0d8a9d571ca3279174ed9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd969d3768e0d8a9d571ca3279174ed9 = L.map(
#                 &quot;map_cd969d3768e0d8a9d571ca3279174ed9&quot;,
#                 {
#                     center: [58.99973712110597, 95.54357719988514],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_cd969d3768e0d8a9d571ca3279174ed9);
#
#
#
#
#
#             var tile_layer_e264abaab183352eef723840f9c1beae = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cd969d3768e0d8a9d571ca3279174ed9);
#
#
#             map_cd969d3768e0d8a9d571ca3279174ed9.fitBounds(
#                 [[45.73825948811118, 29.953814587068525], [72.26121475410076, 161.13333981270173]],
#                 {}
#             );
#
#
#         function geo_json_bc487aa88ef95256bc5d5bd4d19618aa_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;yellow&quot;, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_bc487aa88ef95256bc5d5bd4d19618aa_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_bc487aa88ef95256bc5d5bd4d19618aa_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_bc487aa88ef95256bc5d5bd4d19618aa_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_bc487aa88ef95256bc5d5bd4d19618aa_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_bc487aa88ef95256bc5d5bd4d19618aa.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_bc487aa88ef95256bc5d5bd4d19618aa_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_bc487aa88ef95256bc5d5bd4d19618aa = L.geoJson(null, {
#                 onEachFeature: geo_json_bc487aa88ef95256bc5d5bd4d19618aa_onEachFeature,
#
#                 style: geo_json_bc487aa88ef95256bc5d5bd4d19618aa_styler,
#                 pointToLayer: geo_json_bc487aa88ef95256bc5d5bd4d19618aa_pointToLayer
#         });
#
#         function geo_json_bc487aa88ef95256bc5d5bd4d19618aa_add (data) {
#             geo_json_bc487aa88ef95256bc5d5bd4d19618aa
#                 .addData(data)
#                 .addTo(map_cd969d3768e0d8a9d571ca3279174ed9);
#         }
#             geo_json_bc487aa88ef95256bc5d5bd4d19618aa_add({&quot;bbox&quot;

# %% [markdown]
# ❤
